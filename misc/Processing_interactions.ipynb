# %%
import pandas as pd

# %%
master_df = pd.read_csv("/Users/janzules/Roselab/Spatial/CAR_T/Results/master_df_interactions.csv")

# %%
master_df.columns
# Out:
# Index(['interaction', 'ligand', 'receptor', 'ligand_means', 'ligand_props',
#        'receptor_means', 'receptor_props', 'morans', 'morans_pvals', 'mean',
#        'std', 'condition', 'mouse'],
#       dtype='object')

# %%
subset_df = master_df[(master_df['morans'] > 0.05) | (master_df['morans'] < 0)]

# %%
subset_df.to_csv("/Users/janzules/Roselab/Spatial/CAR_T/Results/subset_master_morans0.09.csv")
