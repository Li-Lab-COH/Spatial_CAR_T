# %%
# pretend this is your AnnData var_names
varnames = ["Csf1r", "Adgre1", "Ltf", "Cd74", "Ly6g"]

# %%
neutrophil_neg = ["Ly6g","Mpo","Elane","S100a8","S100a9","Camp","Ltf"]

# %%
present_neut = [g for g in neutrophil_neg if g in varnames]
print(present_neut)
