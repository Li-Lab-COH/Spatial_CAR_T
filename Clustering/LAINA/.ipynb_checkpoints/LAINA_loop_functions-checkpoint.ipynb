# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'CC_cluster_analysis_.ipynb',
#  'CellCharter.ipynb',
#  'CellCharter_mouse_libraryID.ipynb',
#  'Clustering.ipynb',
#  'LAINA',
#  'LAINA+.ipynb',
#  'pypath_log',
#  'QC_Figures.ipynb',
#  'SpatialAnalysis.ipynb']

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/jonan/Documents/1Work/RoseLab/Spatial/CAR_T/code/Clustering'
