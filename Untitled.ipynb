# %%
import anndata as ad
import squidpy as sq
import cellcharter as cc
import pandas as pd
import scanpy as sc
import scvi
import numpy as np
import matplotlib.pyplot as plt
from lightning.pytorch import seed_everything
from pathlib import Path
from skimage.io import imread
import spatialdata as spd

import torch
torch.set_float32_matmul_precision("high")

seed_everything(1337)
scvi.settings.seed = 1337
# Out:
# /home/janzules/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/janzules/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [rank: 0] Seed set to 1337
# [rank: 0] Seed set to 1337

# %%
zarr_file = "/home/janzules/spatial/CAR-T/data/cell2location/adata/zarrFiles/CellCharterClustered"
zdata = spd.read_zarr(zarr_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 zarr_file = "/home/janzules/spatial/CAR-T/data/cell2location/adata/zarrFiles/CellCharterClustered"
# ----> 2 zdata = spd.read_zarr(zarr_file)
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/spatialdata/_io/io_zarr.py:156, in read_zarr(store, selection, on_bad_files)
#     153 from spatialdata._io._utils import _resolve_zarr_store
#     155 resolved_store = _resolve_zarr_store(store)
# --> 156 root_group = zarr.open_group(resolved_store, mode="r")
#     157 # the following is the SpatialDataContainerFormat version
#     158 if "spatialdata_attrs" not in root_group.metadata.attributes:
#     159     # backward compatibility for pre-versioned SpatialData zarr stores
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/api/synchronous.py:549, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, zarr_format, meta_array, attributes, use_consolidated)
#     478 def open_group(
#     479     store: StoreLike | None = None,
#     480     *,
#    (...)    491     use_consolidated: bool | str | None = None,
#     492 ) -> Group:
#     493     """Open a group using file-mode-like semantics.
#     494
#     495     Parameters
#    (...)    546         The new group.
#     547     """
#     548     return Group(
# --> 549         sync(
#     550             async_api.open_group(
#     551                 store=store,
#     552                 mode=mode,
#     553                 cache_attrs=cache_attrs,
#     554                 synchronizer=synchronizer,
#     555                 path=path,
#     556                 chunk_store=chunk_store,
#     557                 storage_options=storage_options,
#     558                 zarr_version=zarr_version,
#     559                 zarr_format=zarr_format,
#     560                 meta_array=meta_array,
#     561                 attributes=attributes,
#     562                 use_consolidated=use_consolidated,
#     563             )
#     564         )
#     565     )
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/core/sync.py:159, in sync(coro, loop, timeout)
#     156 return_result = next(iter(finished)).result()
#     158 if isinstance(return_result, BaseException):
# --> 159     raise return_result
#     160 else:
#     161     return return_result
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/core/sync.py:119, in _runner(coro)
#     114 """
#     115 Await a coroutine and return the result of running it. If awaiting the coroutine raises an
#     116 exception, the exception will be returned.
#     117 """
#     118 try:
# --> 119     return await coro
#     120 except Exception as ex:
#     121     return ex
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/api/asynchronous.py:860, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, zarr_format, meta_array, attributes, use_consolidated)
#     857 if chunk_store is not None:
#     858     warnings.warn("chunk_store is not yet implemented", ZarrRuntimeWarning, stacklevel=2)
# --> 860 store_path = await make_store_path(store, mode=mode, storage_options=storage_options, path=path)
#     861 if attributes is None:
#     862     attributes = {}
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/storage/_common.py:423, in make_store_path(store_like, path, mode, storage_options)
#     421 else:
#     422     store = await make_store(store_like, mode=mode, storage_options=storage_options)
# --> 423     return await StorePath.open(store, path=path_normalized, mode=mode)
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/storage/_common.py:129, in StorePath.open(cls, store, path, mode)
#     124     except NotImplementedError as e:
#     125         raise ValueError(
#     126             "Store is not read-only but mode is 'r'. Unable to create a read-only copy of the store. "
#     127             "Please use a read-only store or a storage class that implements .with_read_only()."
#     128         ) from e
# --> 129     self = await cls._create_open_instance(read_only_store, path)
#     130 else:
#     131     # writable store and writable mode
#     132     self = await cls._create_open_instance(store, path)
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/storage/_common.py:71, in StorePath._create_open_instance(cls, store, path)
#      68 @classmethod
#      69 async def _create_open_instance(cls, store: Store, path: str) -> Self:
#      70     """Helper to create and return a StorePath instance."""
# ---> 71     await store._ensure_open()
#      72     return cls(store, path)
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/abc/store.py:131, in Store._ensure_open(self)
#     129 """Open the store if it is not already open."""
#     130 if not self._is_open:
# --> 131     await self._open()
#
# File ~/mamba_envs/spatial_gpu_py311/lib/python3.11/site-packages/zarr/storage/_local.py:172, in LocalStore._open(self, mode)
#     169     self.root.mkdir(parents=True, exist_ok=True)
#     171 if not self.root.exists():
# --> 172     raise FileNotFoundError(f"{self.root} does not exist")
#     173 return await super()._open()
#
# FileNotFoundError: /home/janzules/spatial/CAR-T/data/cell2location/adata/zarrFiles/CellCharterClustered does not exist

# %%
ST_sample = zdata.tables["segmentation_counts"]

# %%
ST_sample
# Out:
# AnnData object with n_obs × n_vars = 427296 × 19059
#     obs: 'sample', 'cell_id', 'region', 'TMA', 'mouse', 'tissue', 'condition', 'tumor_loc', 'replicate_num', '_indices', '_scvi_batch', '_scvi_labels', 'batch_core', 'c2l_label_perm', 'c2l_label_strict', 'mt_counts', 'total_RNA_counts', 'treatment'
#     uns: 'spatialdata_attrs', 'cell2location_provenance'
#     obsm: 'spatial'
