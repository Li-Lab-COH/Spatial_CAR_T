# %% [markdown]
# # Packages

# %%
import numpy as np
import pandas as pd
import squidpy as sq
from pathlib import Path
import os

# %% [markdown]
# # Data

# %%
# Locations
proj_folder   = Path("/coh_labs/yunroseli/Jona/CAR-T/")
C2L_files     = proj_folder / "cell2location/C2L_inputs"
fig_folder    = proj_folder / "figures/co_loco"

# fig_folder.mkdir(exist_ok=True)

# Data
adata_file    = C2L_files / "predicted_cells_lvl2_epochs_200_Ncells1_decalpha_100.h5ad"
