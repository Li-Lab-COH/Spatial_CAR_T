# %%
import spatialdata as spd
from pathlib import Path
# Out:
# /Users/janzules/miniforge3/envs/vishd_10x/lib/python3.11/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/janzules/miniforge3/envs/vishd_10x/lib/python3.11/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
tissue_concat_zarr = Path("/Users/janzules/Roselab/Spatial/CAR_T/data/zarrFiles/concatenated_tissues_sdata_second_run")

sdata = spd.read_zarr(tissue_concat_zarr)
# Out:
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /Users/janzules/miniforge3/envs/vishd_10x/lib/python3.11/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# version mismatch: detected: RasterFormatV02, requested: FormatV04

# %%
sdata
# Out:
# SpatialData object, with associated Zarr store: /Users/janzules/Roselab/Spatial/CAR_T/data/zarrFiles/concatenated_tissues_sdata_second_run
# ├── Images
# │     ├── 'CyPSCA_1_1_hires_tissue_image': DataArray[cyx] (3, 2645, 2706)
# │     ├── 'CyPSCA_1_2_hires_tissue_image': DataArray[cyx] (3, 2348, 2448)
# │     ├── 'CyPSCA_2_4_hires_tissue_image': DataArray[cyx] (3, 2445, 2505)
# │     ├── 'CyT72_1_2_hires_tissue_image': DataArray[cyx] (3, 2202, 2308)
# │     ├── 'CyT72_1_4_hires_tissue_image': DataArray[cyx] (3, 2224, 2060)
# │     ├── 'CyT72_2_3_hires_tissue_image': DataArray[cyx] (3, 2480, 2363)
# │     ├── 'NoTx_1_4_hires_tissue_image': DataArray[cyx] (3, 2600, 1799)
# │     ├── 'NoTx_2_2_hires_tissue_image': DataArray[cyx] (3, 2668, 2533)
# │     ├── 'NoTx_2_4_hires_tissue_image': DataArray[cyx] (3, 2494, 2542)
# │     ├── 'RTCyPSCA_1_3_hires_tissue_image': DataArray[cyx] (3, 2355, 2630)
# │     ├── 'RTCyPSCA_1_4_hires_tissue_image': DataArray[cyx] (3, 2658, 2085)
# │     ├── 'RTCyPSCA_2_3_hires_tissue_image': DataArray[cyx] (3, 2897, 2837)
# │     ├── 'RTCyPSCA_2_4_hires_tissue_image': DataArray[cyx] (3, 2513, 2669)
# │     ├── 'RTCyT72_1_1_hires_tissue_image': DataArray[cyx] (3, 2012, 1773)
# │     ├── 'RTCyT72_2_1_hires_tissue_image': DataArray[cyx] (3, 2434, 2194)
# │     └── 'RTCyT72_2_4_hires_tissue_image': DataArray[cyx] (3, 2597, 2416)
# ├── Shapes
# │     ├── 'CyPSCA_1_1_cell_boundaries': GeoDataFrame shape: (45836, 2) (2D shapes)
# │     ├── 'CyPSCA_1_1_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'CyPSCA_1_2_cell_boundaries': GeoDataFrame shape: (22650, 2) (2D shapes)
# │     ├── 'CyPSCA_1_2_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'CyPSCA_2_4_cell_boundaries': GeoDataFrame shape: (16127, 2) (2D shapes)
# │     ├── 'CyPSCA_2_4_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'CyT72_1_2_cell_boundaries': GeoDataFrame shape: (5242, 2) (2D shapes)
# │     ├── 'CyT72_1_2_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'CyT72_1_4_cell_boundaries': GeoDataFrame shape: (26153, 2) (2D shapes)
# │     ├── 'CyT72_1_4_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'CyT72_2_3_cell_boundaries': GeoDataFrame shape: (17859, 2) (2D shapes)
# │     ├── 'CyT72_2_3_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'NoTx_1_4_cell_boundaries': GeoDataFrame shape: (14820, 2) (2D shapes)
# │     ├── 'NoTx_1_4_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'NoTx_2_2_cell_boundaries': GeoDataFrame shape: (65864, 2) (2D shapes)
# │     ├── 'NoTx_2_2_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'NoTx_2_4_cell_boundaries': GeoDataFrame shape: (31434, 2) (2D shapes)
# │     ├── 'NoTx_2_4_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'RTCyPSCA_1_3_cell_boundaries': GeoDataFrame shape: (17083, 2) (2D shapes)
# │     ├── 'RTCyPSCA_1_3_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'RTCyPSCA_1_4_cell_boundaries': GeoDataFrame shape: (28353, 2) (2D shapes)
# │     ├── 'RTCyPSCA_1_4_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'RTCyPSCA_2_3_cell_boundaries': GeoDataFrame shape: (19117, 2) (2D shapes)
# │     ├── 'RTCyPSCA_2_3_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'RTCyPSCA_2_4_cell_boundaries': GeoDataFrame shape: (27950, 2) (2D shapes)
# │     ├── 'RTCyPSCA_2_4_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'RTCyT72_1_1_cell_boundaries': GeoDataFrame shape: (2747, 2) (2D shapes)
# │     ├── 'RTCyT72_1_1_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'RTCyT72_2_1_cell_boundaries': GeoDataFrame shape: (38821, 2) (2D shapes)
# │     ├── 'RTCyT72_2_1_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# │     ├── 'RTCyT72_2_4_cell_boundaries': GeoDataFrame shape: (47262, 2) (2D shapes)
# │     └── 'RTCyT72_2_4_roi': GeoDataFrame shape: (1, 1) (2D shapes)
# └── Tables
#       └── 'segmentation_counts': AnnData (427318, 19059)
# with coordinate systems:
#     ▸ 'downscale_to_hires', with elements:
#         CyPSCA_1_1_hires_tissue_image (Images), CyPSCA_1_2_hires_tissue_image (Images), CyPSCA_2_4_hires_tissue_image (Images), CyT72_1_2_hires_tissue_image (Images), CyT72_1_4_hires_tissue_image (Images), CyT72_2_3_hires_tissue_image (Images), NoTx_1_4_hires_tissue_image (Images), NoTx_2_2_hires_tissue_image (Images), NoTx_2_4_hires_tissue_image (Images), RTCyPSCA_1_3_hires_tissue_image (Images), RTCyPSCA_1_4_hires_tissue_image (Images), RTCyPSCA_2_3_hires_tissue_image (Images), RTCyPSCA_2_4_hires_tissue_image (Images), RTCyT72_1_1_hires_tissue_image (Images), RTCyT72_2_1_hires_tissue_image (Images), RTCyT72_2_4_hires_tissue_image (Images), CyPSCA_1_1_cell_boundaries (Shapes), CyPSCA_1_1_roi (Shapes), CyPSCA_1_2_cell_boundaries (Shapes), CyPSCA_1_2_roi (Shapes), CyPSCA_2_4_cell_boundaries (Shapes), CyPSCA_2_4_roi (Shapes), CyT72_1_2_cell_boundaries (Shapes), CyT72_1_2_roi (Shapes), CyT72_1_4_cell_boundaries (Shapes), CyT72_1_4_roi (Shapes), CyT72_2_3_cell_boundaries (Shapes), CyT72_2_3_roi (Shapes), NoTx_1_4_cell_boundaries (Shapes), NoTx_1_4_roi (Shapes), NoTx_2_2_cell_boundaries (Shapes), NoTx_2_2_roi (Shapes), NoTx_2_4_cell_boundaries (Shapes), NoTx_2_4_roi (Shapes), RTCyPSCA_1_3_cell_boundaries (Shapes), RTCyPSCA_1_3_roi (Shapes), RTCyPSCA_1_4_cell_boundaries (Shapes), RTCyPSCA_1_4_roi (Shapes), RTCyPSCA_2_3_cell_boundaries (Shapes), RTCyPSCA_2_3_roi (Shapes), RTCyPSCA_2_4_cell_boundaries (Shapes), RTCyPSCA_2_4_roi (Shapes), RTCyT72_1_1_cell_boundaries (Shapes), RTCyT72_1_1_roi (Shapes), RTCyT72_2_1_cell_boundaries (Shapes), RTCyT72_2_1_roi (Shapes), RTCyT72_2_4_cell_boundaries (Shapes), RTCyT72_2_4_roi (Shapes)
